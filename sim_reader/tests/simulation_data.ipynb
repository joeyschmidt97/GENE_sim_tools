# %%
import os

from GENE_sim_tools.GENE_sim_reader.src.dict_simulation_data import filepath_to_simulation_dict_list, sim_filepath_to_df
from GENE_sim_tools.GENE_sim_reader.src.utils.find_buried_filetypes import find_buried_filetypes

# %%
# path1 = '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.936008_OM_top/MTM_limit/kymin_0.1/scanfiles0000/parameters_0007'
# path2 = '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.936008_OM_top/MTM_limit/kymin_0.1/scanfiles0000/parameters_0005'
path3 = '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.936008_OM_top/MTM_limit/kymin_0.1/scanfiles0000'

path_list = path3
crit4 = ['status==CONVERGED', 'nrg', 'time==last', 'omega', 'gamma', 'field_phi', 'field_apar']

sim_df = sim_filepath_to_df(path_list, crit4)



print(type(sim_df['Q_ES1'][0]), '\n')
print(sim_df['Q_ES1'], '\n')
print(sim_df['time'], '\n')

# print(len(sim_df['time'][0]), len(sim_df['time'][1]), len(sim_df['time'][2]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 8
#       5 path_list = path3
#       6 crit4 = ['status==CONVERGED', 'nrg', 'time==last', 'omega', 'gamma', 'field_phi', 'field_apar']
# ----> 8 sim_df = sim_filepath_to_df(path_list, crit4)
#      12 print(type(sim_df['Q_ES1'][0]), '\n')
#      13 print(sim_df['Q_ES1'], '\n')
#
# File ~/tools/GENE_sim_tools/GENE_sim_reader/src/dict_simulation_data.py:251, in sim_filepath_to_df(filepath_list, criteria_list, load_spec)
#     249 def sim_filepath_to_df(filepath_list, criteria_list=[], load_spec='all'):
# --> 251     sim_dict_list, _ = filepath_to_simulation_dict_list(filepath_list, criteria_list, load_spec)
#     252     flat_sim_data_list = []
#     254     for sim in sim_dict_list:
#
# File ~/tools/GENE_sim_tools/GENE_sim_reader/src/dict_simulation_data.py:57, in filepath_to_simulation_dict_list(filepath_list, criteria_list, load_spec, debug)
#      52 else:
#      53     # Process each 'parameters' file found
#      54     for parameter_filepath in parameter_filepath_list:
#      55
#      56         # Convert file paths to dictionaries containing simulation information
# ---> 57         simulation_dict, criteria_per_dict = create_sim_dict(parameter_filepath, criteria_list, load_spec)
#      59         if simulation_dict == False:
#      60             continue
#
# File ~/tools/GENE_sim_tools/GENE_sim_reader/src/dict_simulation_data.py:129, in create_sim_dict(parameter_filepath, criteria_list, load_spec)
#     127 # Convert the criteria list into a list of criteria dict and group them by which criteria goes to which dict type
#     128 criteria_dict_list = multi_criteria_to_list(criteria_list)
# --> 129 criteria_per_dict = load_criteria_per_dict(criteria_dict_list, parameter_dict, species_tuple)
#     132 if 'simulation' in list(criteria_per_dict.keys()):
#     133     add_simulation = dict_criteria_check(criteria_per_dict['simulation'], simulation_dict)
#
# File ~/tools/GENE_sim_tools/GENE_sim_reader/src/filetype_key_lists.py:89, in load_criteria_per_dict(criteria_dict_list, param_dict, species_tuple)
#      86         variable_found = True
#      88     if not variable_found:
# ---> 89         raise ValueError(f'Please ensure "{variable_name}" is a valid name found in one of the GENE filetypes')
#      91         # TODO - add user input to ask which filetype keys they want to see (i.e. omega, nrg, etc.) and print these keys
#      96 keys_to_remove = []
#
# ValueError: Please ensure "nrg" is a valid name found in one of the GENE filetypes

# %%
sim_df
# Out:
#                                             directory suffix     status  \
# 0   /pscratch/sd/j/joeschm/NSXTU_discharges/129015...   0001  CONVERGED
# 1   /pscratch/sd/j/joeschm/NSXTU_discharges/129015...   0002  CONVERGED
# 2   /pscratch/sd/j/joeschm/NSXTU_discharges/129015...   0003  CONVERGED
# 3   /pscratch/sd/j/joeschm/NSXTU_discharges/129015...   0004  CONVERGED
# 4   /pscratch/sd/j/joeschm/NSXTU_discharges/129015...   0005  CONVERGED
# 5   /pscratch/sd/j/joeschm/NSXTU_discharges/129015...   0006  CONVERGED
# 6   /pscratch/sd/j/joeschm/NSXTU_discharges/129015...   0007  CONVERGED
# 7   /pscratch/sd/j/joeschm/NSXTU_discharges/129015...   0008  CONVERGED
# 8   /pscratch/sd/j/joeschm/NSXTU_discharges/129015...   0009  CONVERGED
# 9   /pscratch/sd/j/joeschm/NSXTU_discharges/129015...   0010  CONVERGED
# 10  /pscratch/sd/j/joeschm/NSXTU_discharges/129015...   0011  CONVERGED
# 11  /pscratch/sd/j/joeschm/NSXTU_discharges/129015...   0012  CONVERGED
# 12  /pscratch/sd/j/joeschm/NSXTU_discharges/129015...   0013  CONVERGED
# 13  /pscratch/sd/j/joeschm/NSXTU_discharges/129015...   0014  CONVERGED
# 14  /pscratch/sd/j/joeschm/NSXTU_discharges/129015...   0015  CONVERGED
# 15  /pscratch/sd/j/joeschm/NSXTU_discharges/129015...   0016  CONVERGED
# 16  /pscratch/sd/j/joeschm/NSXTU_discharges/129015...   0017  CONVERGED
# 17  /pscratch/sd/j/joeschm/NSXTU_discharges/129015...   0018  CONVERGED
# 18  /pscratch/sd/j/joeschm/NSXTU_discharges/129015...   0019  CONVERGED
# 19  /pscratch/sd/j/joeschm/NSXTU_discharges/129015...   0020  CONVERGED
# 20  /pscratch/sd/j/joeschm/NSXTU_discharges/129015...   0021  CONVERGED
# 21  /pscratch/sd/j/joeschm/NSXTU_discharges/129015...   0022  CONVERGED
# 22  /pscratch/sd/j/joeschm/NSXTU_discharges/129015...   0023  CONVERGED
# 23  /pscratch/sd/j/joeschm/NSXTU_discharges/129015...   0024  CONVERGED
# 24  /pscratch/sd/j/joeschm/NSXTU_discharges/129015...   0025  CONVERGED
# 25  /pscratch/sd/j/joeschm/NSXTU_discharges/129015...   0026  CONVERGED
# 26  /pscratch/sd/j/joeschm/NSXTU_discharges/129015...   0027  CONVERGED
#
#                                  simulation_filepaths  \
# 0   [/pscratch/sd/j/joeschm/NSXTU_discharges/12901...
# 1   [/pscratch/sd/j/joeschm/NSXTU_discharges/12901...
# 2   [/pscratch/sd/j/joeschm/NSXTU_discharges/12901...
# 3   [/pscratch/sd/j/joeschm/NSXTU_discharges/12901...
# 4   [/pscratch/sd/j/joeschm/NSXTU_discharges/12901...
# 5   [/pscratch/sd/j/joeschm/NSXTU_discharges/12901...
# 6   [/pscratch/sd/j/joeschm/NSXTU_discharges/12901...
# 7   [/pscratch/sd/j/joeschm/NSXTU_discharges/12901...
# 8   [/pscratch/sd/j/joeschm/NSXTU_discharges/12901...
# 9   [/pscratch/sd/j/joeschm/NSXTU_discharges/12901...
# 10  [/pscratch/sd/j/joeschm/NSXTU_discharges/12901...
# 11  [/pscratch/sd/j/joeschm/NSXTU_discharges/12901...
# 12  [/pscratch/sd/j/joeschm/NSXTU_discharges/12901...
# 13  [/pscratch/sd/j/joeschm/NSXTU_discharges/12901...
# 14  [/pscratch/sd/j/joeschm/NSXTU_discharges/12901...
# 15  [/pscratch/sd/j/joeschm/NSXTU_discharges/12901...
# 16  [/pscratch/sd/j/joeschm/NSXTU_discharges/12901...
# 17  [/pscratch/sd/j/joeschm/NSXTU_discharges/12901...
# 18  [/pscratch/sd/j/joeschm/NSXTU_discharges/12901...
# 19  [/pscratch/sd/j/joeschm/NSXTU_discharges/12901...
# 20  [/pscratch/sd/j/joeschm/NSXTU_discharges/12901...
# 21  [/pscratch/sd/j/joeschm/NSXTU_discharges/12901...
# 22  [/pscratch/sd/j/joeschm/NSXTU_discharges/12901...
# 23  [/pscratch/sd/j/joeschm/NSXTU_discharges/12901...
# 24  [/pscratch/sd/j/joeschm/NSXTU_discharges/12901...
# 25  [/pscratch/sd/j/joeschm/NSXTU_discharges/12901...
# 26  [/pscratch/sd/j/joeschm/NSXTU_discharges/12901...
#
#                                      key_list                   species_info  \
# 0   [time, field_phi, field_apar, field_bpar]  (((i, 1), (e, 2), (c, 3)), 3)
# 1   [time, field_phi, field_apar, field_bpar]  (((i, 1), (e, 2), (c, 3)), 3)
# 2   [time, field_phi, field_apar, field_bpar]  (((i, 1), (e, 2), (c, 3)), 3)
# 3   [time, field_phi, field_apar, field_bpar]  (((i, 1), (e, 2), (c, 3)), 3)
# 4   [time, field_phi, field_apar, field_bpar]  (((i, 1), (e, 2), (c, 3)), 3)
# 5   [time, field_phi, field_apar, field_bpar]  (((i, 1), (e, 2), (c, 3)), 3)
# 6   [time, field_phi, field_apar, field_bpar]  (((i, 1), (e, 2), (c, 3)), 3)
# 7   [time, field_phi, field_apar, field_bpar]  (((i, 1), (e, 2), (c, 3)), 3)
# 8   [time, field_phi, field_apar, field_bpar]  (((i, 1), (e, 2), (c, 3)), 3)
# 9   [time, field_phi, field_apar, field_bpar]  (((i, 1), (e, 2), (c, 3)), 3)
# 10  [time, field_phi, field_apar, field_bpar]  (((i, 1), (e, 2), (c, 3)), 3)
# 11  [time, field_phi, field_apar, field_bpar]  (((i, 1), (e, 2), (c, 3)), 3)
# 12  [time, field_phi, field_apar, field_bpar]  (((i, 1), (e, 2), (c, 3)), 3)
# 13  [time, field_phi, field_apar, field_bpar]  (((i, 1), (e, 2), (c, 3)), 3)
# 14  [time, field_phi, field_apar, field_bpar]  (((i, 1), (e, 2), (c, 3)), 3)
# 15  [time, field_phi, field_apar, field_bpar]  (((i, 1), (e, 2), (c, 3)), 3)
# 16  [time, field_phi, field_apar, field_bpar]  (((i, 1), (e, 2), (c, 3)), 3)
# 17  [time, field_phi, field_apar, field_bpar]  (((i, 1), (e, 2), (c, 3)), 3)
# 18  [time, field_phi, field_apar, field_bpar]  (((i, 1), (e, 2), (c, 3)), 3)
# 19  [time, field_phi, field_apar, field_bpar]  (((i, 1), (e, 2), (c, 3)), 3)
# 20  [time, field_phi, field_apar, field_bpar]  (((i, 1), (e, 2), (c, 3)), 3)
# 21  [time, field_phi, field_apar, field_bpar]  (((i, 1), (e, 2), (c, 3)), 3)
# 22  [time, field_phi, field_apar, field_bpar]  (((i, 1), (e, 2), (c, 3)), 3)
# 23  [time, field_phi, field_apar, field_bpar]  (((i, 1), (e, 2), (c, 3)), 3)
# 24  [time, field_phi, field_apar, field_bpar]  (((i, 1), (e, 2), (c, 3)), 3)
# 25  [time, field_phi, field_apar, field_bpar]  (((i, 1), (e, 2), (c, 3)), 3)
# 26  [time, field_phi, field_apar, field_bpar]  (((i, 1), (e, 2), (c, 3)), 3)
#
#     n_procs_s  n_procs_v  n_procs_w  n_procs_x  ...  omega         Q_ES1  \
# 0           1          2          4          1  ...  0.090  3.698400e+26
# 1           1          2          4          1  ... -3.363  6.244300e+21
# 2           1          2          4          1  ... -3.445  3.078200e+23
# 3           1          2          4          1  ...  0.089  6.885600e-01
# 4           1          2          4          1  ... -3.366  1.042500e+03
# 5           1          2          4          1  ... -3.448  4.879100e+26
# 6           1          2          4          1  ...  0.088  3.597900e+02
# 7           1          2          4          1  ... -3.367  9.242400e+26
# 8           1          2          4          1  ... -3.448  3.813200e+00
# 9           1          2          4          1  ...  0.093  2.328600e+06
# 10          1          2          4          1  ... -3.358  2.604000e+08
# 11          1          2          4          1  ... -3.441  2.534700e+13
# 12          1          2          4          1  ...  0.092  5.485800e+01
# 13          1          2          4          1  ... -3.363  4.961400e+00
# 14          1          2          4          1  ... -3.445  1.537300e+19
# 15          1          2          4          1  ...  0.092  1.025100e+02
# 16          1          2          4          1  ... -3.364  1.295100e+26
# 17          1          2          4          1  ... -3.446  1.606000e-02
# 18          1          2          4          1  ...  0.076  3.079400e+06
# 19          1          2          4          1  ... -3.355  1.587900e+23
# 20          1          2          4          1  ... -3.438  5.953100e+27
# 21          1          2          4          1  ...  0.074  7.163700e+04
# 22          1          2          4          1  ... -3.360  2.036500e+17
# 23          1          2          4          1  ... -3.443  2.177400e+00
# 24          1          2          4          1  ...  0.073  1.175900e+00
# 25          1          2          4          1  ... -3.362  2.740500e+04
# 26          1          2          4          1  ... -3.445  1.472100e+06
#
#            Q_EM1         Q_ES2         Q_EM2         Q_ES3         Q_EM3  \
# 0  -2.324700e+25  2.063600e+26  4.412300e+25  5.290800e+25 -1.066900e+24
# 1   2.903700e+20  2.827400e+22  2.411400e+21  4.432100e+19  8.953000e+18
# 2   1.235900e+22  1.295500e+24  8.494700e+22  1.228400e+22  3.786500e+20
# 3  -3.361600e-02  3.687700e-01  7.138900e-02  9.629900e-02 -1.680400e-03
# 4   4.786600e+01  4.476300e+03  3.630400e+02  1.327000e+01  1.434400e+00
# 5   2.002300e+25  2.004000e+27  1.259500e+26  2.001100e+25  5.937100e+23
# 6  -1.362600e+01  1.856400e+02  3.343500e+01  4.946500e+01 -7.448500e-01
# 7   4.313200e+25  3.878900e+27  3.044500e+26  1.294400e+25  1.254100e+24
# 8   1.502400e-01  1.458500e+01  8.853100e-01  1.742200e-01  4.374200e-03
# 9  -2.769300e+05  2.145200e+06  4.290200e+05  2.734700e+05 -1.420200e+04
# 10  1.340600e+07  1.174300e+09  1.036700e+08 -1.970900e+06  4.059600e+05
# 11  1.157200e+12  1.076300e+14  7.540000e+12  6.126200e+11  3.469000e+10
# 12 -5.403000e+00  4.908400e+01  9.557400e+00  6.409900e+00 -2.882700e-01
# 13  2.601000e-01  2.181200e+01  1.867900e+00 -2.895600e-02  7.640800e-03
# 14  6.939300e+17  6.204700e+19  4.215400e+18  4.325500e+17  2.034200e+16
# 15 -8.380900e+00  8.916600e+01  1.729900e+01  1.195000e+01 -4.652900e-01
# 16  6.711200e+24  5.440700e+26  4.556600e+25 -1.564600e+23  1.926300e+23
# 17  7.343300e-04  6.313400e-02  4.244800e-03  4.778600e-04  2.094300e-05
# 18 -5.464400e+05  4.483600e+06  6.885400e+05  3.068200e+05 -2.960700e+04
# 19  9.396700e+21  7.197000e+23  6.837200e+22 -4.586300e+21  2.762100e+20
# 20  3.097400e+26  2.494400e+28  1.942400e+27  3.721400e+25  9.060200e+24
# 21 -1.129300e+04  1.032000e+05  1.686400e+04  7.182600e+03 -6.154900e+02
# 22  1.181300e+16  8.722100e+17  8.075300e+16 -4.267900e+15  3.413200e+14
# 23  1.136300e-01  8.782500e+00  6.758800e-01  2.219700e-02  3.251300e-03
# 24 -1.648000e-01  1.674100e+00  2.944700e-01  1.187600e-01 -9.034100e-03
# 25  1.595700e+03  1.137300e+05  1.043500e+04 -4.539900e+02  4.499000e+01
# 26  7.714000e+04  5.734600e+06  4.421900e+05  2.056300e+04  2.158100e+03
#
#           time                                          field_phi  \
# 0    634.60956  [[[(-10475313042367.639+2422236735717.0376j), ...
# 1    218.88816  [[[(349006179009.0783+197441488813.80853j), (-...
# 2     92.78754  [[[(-1479071349483.5522+2205213382067.8447j), ...
# 3    471.25710  [[[(0.38145590210762675+0.2770234886973314j), ...
# 4    245.20910  [[[(98.86506851235829-126.0954440647212j), (36...
# 5     96.63552  [[[(40086924542276.56+97114052544308.55j), (-2...
# 6    334.86892  [[[(7.354121745602848+8.184585869490034j), (-1...
# 7    310.33918  [[[(129186215488075.89-76514276246204.9j), (26...
# 8    104.74146  [[[(-0.915196647665884-8.95998899989139j), (2....
# 9    661.75526  [[[(55.1072528213228+591.5596535453041j), (-49...
# 10   275.93258  [[[(-11454.973331101433-78606.51209530588j), (...
# 11   157.30664  [[[(21493752.394270215+9508483.226132736j), (-...
# 12   469.10258  [[[(-1.5454065719626087+2.581895750514037j), (...
# 13   335.25744  [[[(3.340948302520568-10.351664260651008j), (2...
# 14   164.62652  [[[(17393452790.093357-4264464176.1076016j), (...
# 15   326.23318  [[[(1.6346797697576907+3.98492637087411j), (-4...
# 16   498.43584  [[[(-34042282526345.082+42626271295634.98j), (...
# 17   183.80528  [[[(-0.5030881895242151+0.27782565928562697j),...
# 18   258.52242  [[[(-344.7444626268822-184.82912615678035j), (...
# 19   758.40318  [[[(489419197246.3937+1827593900540.348j), (-5...
# 20    99.15486  [[[(329337193192260.5-92510348274135.95j), (40...
# 21   232.21134  [[[(26.35140091609673+60.29499921707642j), (-5...
# 22   994.20502  [[[(-2055190510.5130644-365318251.79102343j), ...
# 23   102.67524  [[[(6.2166411844568765-1.7123147920354638j), (...
# 24   199.89354  [[[(-0.018643165180355428-0.29267386386358507j...
# 25  3027.91296  [[[(636.9235773164532-408.26609397627175j), (1...
# 26   113.62444  [[[(4705.269871141768-2320.4551319372936j), (1...
#
#                                            field_apar
# 0   [[[(10979686563.241896+44219053061.140175j), (...
# 1   [[[(667578193.337661-2388270516.350554j), (-36...
# 2   [[[(15821782204.894613+5762509536.5479j), (186...
# 3   [[[(0.0012083897438988642-0.001576980543639676...
# 4   [[[(-0.8986965074297576-0.4031236899458012j), ...
# 5   [[[(533416299475.4804-392123908024.6608j), (-8...
# 6   [[[(0.035954067142532-0.028584799781160714j), ...
# 7   [[[(-643927887938.4429-651917959356.2076j), (-...
# 8   [[[(-0.05298140707205984+0.019059414409598345j...
# 9   [[[(2.0951346568783156+0.9589660361705467j), (...
# 10  [[[(-481.73257520208995+198.268351068106j), (5...
# 11  [[[(26931.263492086182-155747.63287753222j), (...
# 12  [[[(0.0058878673237117915+0.010581519858702556...
# 13  [[[(-0.07075504445239951-0.004604671153333243j...
# 14  [[[(-55980961.82845505-105720066.21705496j), (...
# 15  [[[(0.017523469515378986+0.002353508425823388j...
# 16  [[[(321519816428.3022+145536948545.18112j), (1...
# 17  [[[(0.0026036352671045754+0.002780020850528624...
# 18  [[[(-4.3111383508722625+1.2431968140800662j), ...
# 19  [[[(11454934976.870949-6438316285.65177j), (-1...
# 20  [[[(-1219382142907.6716-2108734438907.02j), (-...
# 21  [[[(0.657879571167059+0.25601593732057004j), (...
# 22  [[[(1095442.236950766+14358913.515422713j), (2...
# 23  [[[(-0.022692439786104027-0.03955056262263488j...
# 24  [[[(-0.0022325330347606615-0.00191809442124909...
# 25  [[[(-3.801032240074701-3.5176557447664605j), (...
# 26  [[[(-24.03888976159235-27.85608619535992j), (-...
#
# [27 rows x 132 columns]

# %%
filepath = '/pscratch/sd/j/joeschm/NSXTU_discharges/X_TEST'

sim_list, _ = filepath_to_simulation_dict_list(filepath, [], 'e')

param_paths = find_buried_filetypes(filepath, 'parameters')
assert (len(sim_list) == len(param_paths))


# Check convergence of simulations

conv = 0
nonconv = 0

for sim in sim_list:

    print(sim.keys())
    # sim_key_list = ['directory', 'suffix', 'status', 'simulation_filepaths', 'key_list', 'parameters_dict']
    # # assert list(sim.keys()) == sim_key_list

    # print(sim['status'])
    # if sim['status'] == 'CONVERGED':
    #     conv += 1
    # elif sim['status'] == 'NOT_CONVERGED':
    #     nonconv += 1

print('')
print('CONVERGED:', conv)
print('NOT_CONVERGED', nonconv)
# Out:
# dict_keys(['directory', 'suffix', 'status', 'simulation_filepaths', 'key_list', 'species_info', 'parameters_dict'])
# dict_keys(['directory', 'suffix', 'status', 'simulation_filepaths', 'key_list', 'species_info', 'parameters_dict'])
# dict_keys(['directory', 'suffix', 'status', 'simulation_filepaths', 'key_list', 'species_info', 'parameters_dict'])
# dict_keys(['directory', 'suffix', 'status', 'simulation_filepaths', 'key_list', 'species_info', 'parameters_dict'])
# dict_keys(['directory', 'suffix', 'status', 'simulation_filepaths', 'key_list', 'species_info', 'parameters_dict'])
# dict_keys(['directory', 'suffix', 'status', 'simulation_filepaths', 'key_list', 'species_info', 'parameters_dict'])
# dict_keys(['directory', 'suffix', 'status', 'simulation_filepaths', 'key_list', 'species_info', 'parameters_dict'])
# dict_keys(['directory', 'suffix', 'status', 'simulation_filepaths', 'key_list', 'species_info', 'parameters_dict'])
# dict_keys(['directory', 'suffix', 'status', 'simulation_filepaths', 'key_list', 'species_info', 'parameters_dict'])
# dict_keys(['directory', 'suffix', 'status', 'simulation_filepaths', 'key_list', 'species_info', 'parameters_dict'])
# dict_keys(['directory', 'suffix', 'status', 'simulation_filepaths', 'key_list', 'species_info', 'parameters_dict'])
# dict_keys(['directory', 'suffix', 'status', 'simulation_filepaths', 'key_list', 'species_info', 'parameters_dict'])
# dict_keys(['directory', 'suffix', 'status', 'simulation_filepaths', 'key_list', 'species_info', 'parameters_dict'])
# dict_keys(['directory', 'suffix', 'status', 'simulation_filepaths', 'key_list', 'species_info', 'parameters_dict'])
# dict_keys(['directory', 'suffix', 'status', 'simulation_filepaths', 'key_list', 'species_info', 'parameters_dict'])
# dict_keys(['directory', 'suffix', 'status', 'simulation_filepaths', 'key_list', 'species_info', 'parameters_dict'])
# dict_keys(['directory', 'suffix', 'status', 'simulation_filepaths', 'key_list', 'species_info', 'parameters_dict'])
# dict_keys(['directory', 'suffix', 'status', 'simulation_filepaths', 'key_list', 'species_info', 'parameters_dict'])
# dict_keys(['directory', 'suffix', 'status', 'simulation_filepaths', 'key_list', 'species_info', 'parameters_dict'])
# dict_keys(['directory', 'suffix', 'status', 'simulation_filepaths', 'key_list', 'species_info', 'parameters_dict'])
# dict_keys(['directory', 'suffix', 'status', 'simulation_filepaths', 'key_list', 'species_info', 'parameters_dict'])
# dict_keys(['directory', 'suffix', 'status', 'simulation_filepaths', 'key_list', 'species_info', 'parameters_dict'])
# dict_keys(['directory', 'suffix', 'status', 'simulation_filepaths', 'key_list', 'species_info', 'parameters_dict'])
#
# CONVERGED: 0
# NOT_CONVERGED 0

# %%
filepath = '/pscratch/sd/j/joeschm/NSXTU_discharges/X_TEST'

crit1 = ['status==CONVERGED', 'n_mag', 'time<0.05']
sim_list1, crit_per_dict = filepath_to_simulation_dict_list(filepath, crit1, ['e', 'i'])

print(len(sim_list1))

for sim in sim_list1:

    sim_key_list = ['directory', 'suffix', 'status', 'simulation_filepaths', 'key_list', 'parameters_dict', 'nrg_dict']
    assert list(sim.keys()) == sim_key_list

    # check that all the time values match the given criteria
    assert all(sim['nrg_dict']['time']) < 0.05

    assert 'n_mag1' in list(sim['nrg_dict'].keys())
    assert 'n_mag2' in list(sim['nrg_dict'].keys())

    # print(sim['nrg_dict']['n_mag1'])

    print(sim['directory'])
# Out:
# 16
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[4], line 11
#       8 for sim in sim_list1:
#      10     sim_key_list = ['directory', 'suffix', 'status', 'simulation_filepaths', 'key_list', 'parameters_dict', 'nrg_dict']
# ---> 11     assert list(sim.keys()) == sim_key_list
#      13     # check that all the time values match the given criteria
#      14     assert all(sim['nrg_dict']['time']) < 0.05
#
# AssertionError:

# %%
filepath = '/pscratch/sd/j/joeschm/NSXTU_discharges/X_TEST'

crit2 = ['status==CONVERGED', 'n_mag>0.002', 'time<0.05']

sim_list2, _ = filepath_to_simulation_dict_list(filepath, crit2, ['e', 'i'])

for sim in sim_list2:
    sim_key_list = ['directory', 'suffix', 'status', 'simulation_filepaths', 'key_list', 'parameters_dict', 'nrg_dict']
    assert list(sim.keys()) == sim_key_list

    # check that all the time and density values match the given criteria
    assert all(sim['nrg_dict']['time'] < 0.05)
    assert all(sim['nrg_dict']['n_mag1'] > 0.002)
    assert all(sim['nrg_dict']['n_mag2'] > 0.002)

    print(sim['directory'])
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[4], line 9
#       7 for sim in sim_list2:
#       8     sim_key_list = ['directory', 'suffix', 'status', 'simulation_filepaths', 'key_list', 'parameters_dict', 'nrg_dict']
# ----> 9     assert list(sim.keys()) == sim_key_list
#      11     # check that all the time and density values match the given criteria
#      12     assert all(sim['nrg_dict']['time'] < 0.05)
#
# AssertionError:

# %%
filepath = '/pscratch/sd/j/joeschm/NSXTU_discharges/X_TEST'

crit3 = ['time<0.05', 'gamma>0', 'Q_ES < 3e-2', 'Q_EM', 'Gamma_ES']

sim_list3, _ = filepath_to_simulation_dict_list(filepath, crit3, ['e', 'i'])

print(len(sim_list3))

for sim in sim_list3:


    sim_key_list = ['directory', 'suffix', 'status', 'simulation_filepaths', 'key_list', 'parameters_dict', 'omega_dict', 'nrg_dict']

    # assert list(sim.keys()) == sim_key_list

    # check that all the time and density values match the given criteria
    assert all(sim['nrg_dict']['time'] < 0.05)
    assert sim['omega_dict']['gamma'] > 0
    assert all(sim['nrg_dict']['Q_ES1'] < 3e-2)
    assert all(sim['nrg_dict']['Q_ES2'] < 3e-2)

    print(sim['directory'])
# Out:
# 11
# /pscratch/sd/j/joeschm/NSXTU_discharges/X_TEST/TEST_3spec_k100
# /pscratch/sd/j/joeschm/NSXTU_discharges/X_TEST/scanfiles0002
# /pscratch/sd/j/joeschm/NSXTU_discharges/X_TEST/scanfiles0003
# /pscratch/sd/j/joeschm/NSXTU_discharges/X_TEST/scanfiles0004
# /pscratch/sd/j/joeschm/NSXTU_discharges/X_TEST/scanfiles0004
# /pscratch/sd/j/joeschm/NSXTU_discharges/X_TEST/scanfiles0004
# /pscratch/sd/j/joeschm/NSXTU_discharges/X_TEST/scanfiles0005
# /pscratch/sd/j/joeschm/NSXTU_discharges/X_TEST/scanfiles0005
# /pscratch/sd/j/joeschm/NSXTU_discharges/X_TEST/scanfiles0005
# /pscratch/sd/j/joeschm/NSXTU_discharges/X_TEST/scanfiles0005
# /pscratch/sd/j/joeschm/NSXTU_discharges/X_TEST/scanfiles0005

# %%
single_filepath = '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.936008_OM_top/MTM_limit/kymin_0.1/scanfiles0000/parameters_0007'
# scanfile_filepath = '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.936008_OM_top/MTM_limit/kymin_0.1/scanfiles0000'

# crit4 = ['status==CONVERGED','time==last', 'Q_ES', 'Q_EM', "collision_op=='landau'"]

crit4 = ['status==CONVERGED','time==last', 'Q_ES', 'Q_EM', 'collision_op==landau']
sim_list4, crit_list = filepath_to_simulation_dict_list(single_filepath, criteria_list=crit4)
# sim_list4, crit_list = filepath_to_simulation_dict_list(scanfile_filepath, criteria_list=crit4)

print('number of simulations fetched:', len(sim_list4), '\n')

for sim in sim_list4:

    print(sim.keys())

    for nrg_key in sim['nrg_dict'].keys():
        if ('Q_ES' in nrg_key) or ('Q_EM' in nrg_key) or ('time'==nrg_key):

            print(nrg_key, sim['nrg_dict'][nrg_key])
            assert len(sim['nrg_dict'][nrg_key]) == 1

    print('nrg dict keys:', list(sim['nrg_dict'].keys()), '\n')
# Out:
# number of simulations fetched: 1
#
# dict_keys(['directory', 'suffix', 'status', 'simulation_filepaths', 'key_list', 'species_info', 'parameters_dict', 'nrg_dict'])
# Q_ES1 [359.79]
# Q_EM1 [-13.626]
# Q_ES2 [185.64]
# Q_EM2 [33.435]
# Q_ES3 [49.465]
# Q_EM3 [-0.74485]
# time [334.86892]
# nrg dict keys: ['Q_ES1', 'Q_EM1', 'Q_ES2', 'Q_EM2', 'Q_ES3', 'Q_EM3', 'time', 'filepath', 'key_list']

# %%
path1 = '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.936008_OM_top/MTM_limit/kymin_0.1/scanfiles0000/parameters_0007'
path2 = '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.936008_OM_top/MTM_limit/kymin_0.1/scanfiles0000/parameters_0005'
path3 = '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.936008_OM_top/MTM_limit/kymin_0.1/scanfiles0000/parameters_0006'

path_list = [path1, path2, path3]

crit4 = ['status==CONVERGED', 'Q_ES', 'Q_EM', 'time==last']

sim_df = sim_filepath_to_df(path_list, crit4)



print(type(sim_df['Q_ES1'][0]), '\n')
print(sim_df['Q_ES1'], '\n')
print(sim_df['time'], '\n')

# print(len(sim_df['time'][0]), len(sim_df['time'][1]), len(sim_df['time'][2]))
# Out:
# <class 'numpy.float64'>
#
# 0    1.042500e+03
# 1    4.879100e+26
# 2    3.597900e+02
# Name: Q_ES1, dtype: float64
#
# 0    245.20910
# 1     96.63552
# 2    334.86892
# Name: time, dtype: float64

# %%
print(sim_df)
# Out:
#                                            directory suffix     status  \
# 0  /pscratch/sd/j/joeschm/NSXTU_discharges/129015...   0005  CONVERGED
# 1  /pscratch/sd/j/joeschm/NSXTU_discharges/129015...   0006  CONVERGED
# 2  /pscratch/sd/j/joeschm/NSXTU_discharges/129015...   0007  CONVERGED
#
#                                 simulation_filepaths  \
# 0  [/pscratch/sd/j/joeschm/NSXTU_discharges/12901...
# 1  [/pscratch/sd/j/joeschm/NSXTU_discharges/12901...
# 2  [/pscratch/sd/j/joeschm/NSXTU_discharges/12901...
#
#                                             key_list  \
# 0  [time, n_mag, u_par_mag, T_par_mag, T_perp_mag...
# 1  [time, n_mag, u_par_mag, T_par_mag, T_perp_mag...
# 2  [time, n_mag, u_par_mag, T_par_mag, T_perp_mag...
#
#                     species_info  n_procs_s  n_procs_v  n_procs_w  n_procs_x  \
# 0  (((i, 1), (e, 2), (c, 3)), 3)          1          2          4          1
# 1  (((i, 1), (e, 2), (c, 3)), 3)          1          2          4          1
# 2  (((i, 1), (e, 2), (c, 3)), 3)          1          2          4          1
#
#    ...  mref  is_bsg                                           filepath  \
# 0  ...   2.0   False  /pscratch/sd/j/joeschm/NSXTU_discharges/129015...
# 1  ...   2.0   False  /pscratch/sd/j/joeschm/NSXTU_discharges/129015...
# 2  ...   2.0   False  /pscratch/sd/j/joeschm/NSXTU_discharges/129015...
#
#           Q_ES1         Q_EM1         Q_ES2         Q_EM2         Q_ES3  \
# 0  1.042500e+03  4.786600e+01  4.476300e+03  3.630400e+02  1.327000e+01
# 1  4.879100e+26  2.002300e+25  2.004000e+27  1.259500e+26  2.001100e+25
# 2  3.597900e+02 -1.362600e+01  1.856400e+02  3.343500e+01  4.946500e+01
#
#           Q_EM3       time
# 0  1.434400e+00  245.20910
# 1  5.937100e+23   96.63552
# 2 -7.448500e-01  334.86892
#
# [3 rows x 128 columns]

# %% [markdown]
# # Field data test

# %%
filepath = '/pscratch/sd/j/joeschm/NSXTU_discharges/X_TEST'

crit2 = ['status==CONVERGED', 'field_phi', 'field_bpar', 'time==last']

sim_list2 = sim_filepath_to_df(filepath, crit2)

# %%
print(sim_list2['time'])
# Out:
# 0       0.905840
# 1       2.307144
# 2       1.487475
# 3       0.990388
# 4       0.792610
# 5       0.905840
# 6     158.527040
# 7      34.452600
# 8      85.441480
# 9     175.808900
# 10     50.758290
# 11      6.169380
# 12      2.001118
# 13      1.334441
# 14      0.905840
# 15      0.731609
# Name: time, dtype: float64
